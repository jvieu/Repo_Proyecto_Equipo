# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c10f88d1-3e0d-49b6-b5ae-290fcbecb09a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c10f88d1-3e0d-49b6-b5ae-290fcbecb09a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df=pd.read_csv("charts_fixed.csv")

# %%
df.head()
# Out:
#         pais       fecha  ranking                         cancion  \
# 0  Argentina  2026-03-19        1                        LA VILLA
# 1  Argentina  2026-03-19        2  Cuando No Era Cantante - Remix
# 2  Argentina  2026-03-19        3                       Puñaladas
# 3  Argentina  2026-03-19        4                      Soy Favela
# 4  Argentina  2026-03-19        5          UWAIE - versión cumbia
#
#                                           artista artista_normalizado  \
# 0                      Ryan Castro, Kapo, Gangsta         Ryan Castro
# 1  El Bogueto, Anuel AA, Fuerza Regida, Yung Beef          El Bogueto
# 2                  Lauta, Amigo de Artistas, Tote               Lauta
# 3                                     La T y La M         La T y La M
# 4                                       Max Carra           Max Carra
#
#            fuente
# 0  Spotify Charts
# 1  Spotify Charts
# 2  Spotify Charts
# 3  Spotify Charts
# 4  Spotify Charts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pais                 200 non-null    object
#  1   fecha                200 non-null    object
#  2   ranking              200 non-null    int64
#  3   cancion              200 non-null    object
#  4   artista              200 non-null    object
#  5   artista_normalizado  200 non-null    object
#  6   fuente               200 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 11.1+ KB
